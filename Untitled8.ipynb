# %% [markdown]
# <a href="https://colab.research.google.com/github/FSalteri/OnlineLearning_IPS.ipynb/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
from imblearn.over_sampling import SMOTENC
from imblearn.pipeline import Pipeline as ImbPipeline
from sklearn.compose import ColumnTransformer
import requests
from io import BytesIO
import gzip
import numpy as np

# %%
url = "https://raw.githubusercontent.com/kdemertzis/EKPA/refs/heads/main/Data/pcap_data.csv"
df = pd.read_csv(url)

# %%
column_names = [
    "Avg_syn_flag", "Avg_urg_flag", "Avg_fin_flag", "Avg_ack_flag", "Avg_psh_flag",
    "Avg_rst_flag", "Avg_DNS_pkt", "Avg_TCP_pkt", "Avg_UDP_pkt", "Avg_ICMP_pkt",
    "Min_pkt_size", "Max_pkt_size", "StDev_pkt_size", "Avg_payload_pkt", "Min_TTL",
    "Max_TTL", "StDev_TTL", "Min_win_size", "Max_win_size", "StDev_win_size",
    "Min_pkts_lenght", "Max_pkts_lenght", "StDev_pkts_lenght", "Avg_small_payload_pkt",
    "Avg_payload", "Min_payload", "Max_payload", "StDev_payload", "Avg_DNS_over_TCP",
      "target"]

# %%
df['target'] = df['target'].apply(lambda x: 0 if x == 0 else 1)

# %%
categorical_features = df.select_dtypes(include=['object']).columns.tolist()
numerical_features = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
numerical_features.remove('target')

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_features),
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_features)])

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop(columns=['target']), df['target'], test_size=0.2, random_state=42)

# %%
smote = SMOTENC(categorical_features=[df.columns.get_loc(cat) for cat in categorical_features], random_state=42)

# %%
classifier = RandomForestClassifier(n_estimators=100, random_state=42)

# %%
pipeline = ImbPipeline(steps=[('preprocessor', preprocessor), ('classifier', classifier)])
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['Avg_syn_flag',
#                                                    'Avg_urg_flag',
#                                                    'Avg_fin_flag',
#                                                    'Avg_ack_flag',
#                                                    'Avg_psh_flag',
#                                                    'Avg_rst_flag',
#                                                    'Avg_DNS_pkt', 'Avg_TCP_pkt',
#                                                    'Avg_UDP_pkt',
#                                                    'Avg_ICMP_pkt',
#                                                    'Duration_window_flow',
#                                                    'Avg_delta_time',
#                                                    'Min_delta_time',
# ...

# %%
THRESHOLD = 0.7

# %%
batch_size = 100  # Μέγεθος παρτίδας για συνεχή ενημέρωση
for i in range(0, len(X_test), batch_size):
    X_batch = X_test.iloc[i:i+batch_size]
    y_batch = y_test.iloc[i:i+batch_size]

# %%
 y_proba = pipeline.predict_proba(X_batch)[:, 1]
 y_pred = (y_proba > THRESHOLD).astype(int)

# %%
 pipeline.fit(X_batch, y_batch)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['Avg_syn_flag',
#                                                    'Avg_urg_flag',
#                                                    'Avg_fin_flag',
#                                                    'Avg_ack_flag',
#                                                    'Avg_psh_flag',
#                                                    'Avg_rst_flag',
#                                                    'Avg_DNS_pkt', 'Avg_TCP_pkt',
#                                                    'Avg_UDP_pkt',
#                                                    'Avg_ICMP_pkt',
#                                                    'Duration_window_flow',
#                                                    'Avg_delta_time',
#                                                    'Min_delta_time',
# ...

# %%
 blocked_traffic = sum(y_pred)
 print(f"Batch {i//batch_size + 1}: Αποκλεισμένες ροές: {blocked_traffic}/{len(y_pred)}")
# Out:
# Batch 30: Αποκλεισμένες ροές: 55/94

# %%
y_final_pred = pipeline.predict(X_test)
print("Final Accuracy:", accuracy_score(y_test, y_final_pred))
print(classification_report(y_test, y_final_pred))
# Out:
# Final Accuracy: 0.7969271877087508
#               precision    recall  f1-score   support
#
#            0       0.75      0.59      0.66      1012
#            1       0.81      0.90      0.85      1982
#
#     accuracy                           0.80      2994
#    macro avg       0.78      0.75      0.76      2994
# weighted avg       0.79      0.80      0.79      2994
